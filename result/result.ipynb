# %%
import pandas as pd
import matplotlib.pyplot as plt

result_df = pd.read_csv('q-learning-result.csv', index_col='episode')
result_df
# Out:
#          score   epsilon  steps
# episode
# 0            0  1.000000     33
# 1            0  0.999309     71
# 2            0  0.998619     23
# 3            0  0.997930     15
# 4            0  0.997241     16
# ...        ...       ...    ...
# 9995        34  0.001003    669
# 9996        24  0.001003    337
# 9997        23  0.001002    486
# 9998        16  0.001001    409
# 9999        10  0.001001    141
#
# [10000 rows x 3 columns]

# %%
result_df.describe()
# Out:
#               score       epsilon        steps
# count  10000.000000  10000.000000  10000.00000
# mean      10.569900      0.144670    193.15400
# std        9.950468      0.226954    181.77585
# min        0.000000      0.001001      6.00000
# 25%        2.000000      0.005626     49.00000
# 50%        7.000000      0.031634    126.00000
# 75%       18.000000      0.177859    313.00000
# max       46.000000      1.000000   1643.00000

# %%
scores = result_df['score']
scores_100steps_ma = scores.rolling(window=100).mean()
scores_100steps_ma.dropna(how='any')
# Out:
# episode
# 99       0.23
# 100      0.23
# 101      0.24
# 102      0.26
# 103      0.27
#         ...
# 9995    22.13
# 9996    22.15
# 9997    22.29
# 9998    22.28
# 9999    22.13
# Name: score, Length: 9901, dtype: float64

# %%
result_df.plot(kind='line', y='score')
scores_100steps_ma.plot(kind='line', y='score')
plt.legend(['Score', 'Moving Average'])

# %%
result_df.plot(y='steps')
# Out:
# <Axes: xlabel='episode'>
